# %% [markdown]
# <a href="https://colab.research.google.com/github/pawankalyan-2006/AI_ML_LAB_EXPERIMENT/blob/main/EXP4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sentence = input("Enter a sentence: ")
words = sorted(sentence.split())
sorted_sentence = " ".join(words)
print("Sorted sentence:", sorted_sentence)
# Out:
# Enter a sentence: d h a r u n
# Sorted sentence: a d h n r u
